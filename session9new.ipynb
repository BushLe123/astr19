# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
random_numbers = np.random.uniform(0, 1, 1000)

# %%
plt.hist(random_numbers, bins=100)
plt.xlabel("numbers")
plt.ylabel("frequency")
plt.title("histogram of 1000 numbers between 0-1")
plt.show()
